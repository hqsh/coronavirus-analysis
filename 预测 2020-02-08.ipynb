# %%
from coronavirus_analyzer import CoronavirusAnalyzer, train_and_predict
get_data_params = {}  # 'use_last_ma3': True, 'use_last_ma3_rank': False
xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1,
              'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06,
              'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None,
              'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001,
              'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
predict = train_and_predict('2020-02-01', '2020-02-08', print_log=True, 
                            get_data_params=get_data_params, xgb_params=xgb_params)
# Out:
# 2020-02-08 21:31:59,872 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-01），如下这些地区没有新增的确诊人数：台湾、澳门、西藏，如下这些地区没有任何疫情数据变化：台湾、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9727024003554734
# 2020-02-08 21:32:19,565 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-02），如下这些地区没有新增的确诊人数：台湾、西藏，如下这些地区没有任何疫情数据变化：台湾、澳门、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9732496862094135
# 2020-02-08 21:32:38,998 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-03），如下这些地区没有新增的确诊人数：台湾、澳门、西藏，如下这些地区没有任何疫情数据变化：西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9735348080446586
# 2020-02-08 21:32:57,949 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-04），如下这些地区没有新增的确诊人数：西藏，如下这些地区没有任何疫情数据变化：宁夏、台湾、澳门、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.974866898032313
# 2020-02-08 21:33:18,042 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-05），如下这些地区没有新增的确诊人数：宁夏、台湾、澳门、西藏，如下这些地区没有任何疫情数据变化：西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9762288934583655
# 2020-02-08 21:33:37,808 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-06），如下这些地区没有新增的确诊人数：澳门、西藏，如下这些地区没有任何疫情数据变化：青海、澳门、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9752641754804335
# 2020-02-08 21:33:57,576 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-07），如下这些地区没有新增的确诊人数：青海、澳门、西藏，如下这些地区没有任何疫情数据变化：青海、澳门、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9738698635547652
# 2020-02-08 21:34:17,475 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-08），如下这些地区没有新增的确诊人数：青海、澳门、西藏，如下这些地区没有任何疫情数据变化：青海、澳门、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.9736492907364933

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
analyzer = CoronavirusAnalyzer()
df_predict_real1, df_compare1 = analyzer.get_df_predict_real(predict)
# Out:
# 2020-02-08 21:42:39,055 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-08），如下这些地区没有新增的确诊人数：青海、澳门、西藏，如下这些地区没有任何疫情数据变化：青海、澳门、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
