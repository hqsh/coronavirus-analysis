# %%
from coronavirus_analyzer import CoronavirusAnalyzer, train_and_predict
predict_day_cnt = 1
first_date = '2020-02-01'
last_date = '2020-02-13'
selected_regions = None

get_data_params = {'predict_day_cnt': predict_day_cnt, 'use_best_fit_move_in_injured': True, 'use_last_ma3': True,
                   'selected_regions': selected_regions, 'n_days': 7}
xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 
              'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 
              'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 3, 'missing': None, 
              'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 
              'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
predict = train_and_predict(first_date, last_date, print_log=True, 
                            get_data_params=get_data_params, xgb_params=xgb_params)
# Out:
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 3, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
# 模型 score：0.7938379987495393
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 3, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
# 模型 score：0.8192798839443386
# ...

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
analyzer = CoronavirusAnalyzer()
df_predict_real, df_compare = analyzer.get_df_predict_real(predict)
# Out:
# 2020-02-13 23:32:14,027 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-13），如下这些地区没有新增的确诊人数：广西、台湾、澳门、青海、西藏，如下这些地区没有任何疫情数据变化：台湾、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。

# %%
df_predict_real.iloc[-1, 1::2] = np.nan
df_predict_real
# Out:
#               广东           河南           浙江           安徽          江西        \
#               预测     实际    预测     实际    预测     实际    预测    实际    预测    实际
# 2020-02-01  73.7   84.0  62.4   71.0  69.1   62.0  56.0  43.0  60.4  47.0
# 2020-02-02  63.5   79.0  53.1   73.0  56.6   63.0  55.6  68.0  49.8  58.0
# 2020-02-03  49.6  114.0  59.4  109.0  61.7  105.0  56.7  72.0  51.7  85.0
# 2020-02-04  76.4   73.0  83.2   89.0  79.6   66.0  60.3  50.0  71.4  72.0
# 2020-02-05  63.9   74.0  77.1   87.0  58.3   59.0  58.5  61.0  62.6  52.0
# 2020-02-06  65.1   74.0  71.2   63.0  56.5   52.0  55.7  74.0  56.3  61.0
# 2020-02-07  60.7   57.0  63.0   67.0  51.6   42.0  63.6  68.0  60.1  37.0
# 2020-02-08  43.2   45.0  61.5   52.0  41.1   27.0  64.0  46.0  41.2  42.0
# 2020-02-09  42.6   31.0  44.8   40.0  30.6   17.0  44.8  51.0  32.0  31.0
# 2020-02-10  24.0   26.0  32.2   32.0  22.3   25.0  40.3  30.0  29.9  33.0
# 2020-02-11  23.4   42.0  30.8   30.0  21.3   14.0  30.3  29.0  29.9  40.0
# ...

# %%
df_predict_real.to_excel('预测2020-02-13.xlsx')

# %%
from coronavirus_analyzer import CoronavirusAnalyzer
predict_day_cnt = 1
first_date = '2020-02-01'
last_date = '2020-02-12'
# analyzer = CoronavirusAnalyzer()
# selected_regions = analyzer.get_move_in_injured_corr().sort_values(ascending=False)
# selected_regions = selected_regions[selected_regions > 0.7].index.tolist()
# for r in ['武汉', '湖北', '香港', '澳门', '台湾']:
#     if r in selected_regions:
#         selected_regions.remove(r)
# print('selected_regions count: {}. {}'.format(len(selected_regions), selected_regions))
selected_regions = None

# %%
from coronavirus_analyzer import CoronavirusAnalyzer, train_and_predict
get_data_params = {'predict_day_cnt': predict_day_cnt, 'use_best_fit_move_in_injured': True, 'use_last_ma3': True,
                   'selected_regions': selected_regions, 'n_days': 7}  # , 'use_move_out': True
# xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1,
#               'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06,
#               'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None,
#               'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001,
#               'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 
#               'colsample_bytree': 0.9, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.06, 
#               'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 
#               'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 
#               'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# # xgb_params = {}
xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 
              'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 
              'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 3, 'missing': None, 
              'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 
              'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
predict = train_and_predict(first_date, last_date, print_log=True, 
                            get_data_params=get_data_params, xgb_params=xgb_params)
# Out:
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 3, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
# 模型 score：0.7938379987495393
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 3, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
# 模型 score：0.8192798839443386
# ...

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
analyzer = CoronavirusAnalyzer()
df_predict_real3, df_compare3 = analyzer.get_df_predict_real(predict, 2)
# Out:
# 2020-02-13 23:28:23,839 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-13），如下这些地区没有新增的确诊人数：广西、台湾、澳门、青海、西藏，如下这些地区没有任何疫情数据变化：台湾、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。

# %%
# xgb_params = {
#     '2020-02-01': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.7, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 11, 'min_child_weight': 2, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 1, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
#     '2020-02-02': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.8, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.04, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': None, 'n_estimators': 90, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.01, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
#     '2020-02-03': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.7, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 14, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 1, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
#     '2020-02-04': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.7, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 14, 'min_child_weight': 1, 'missing': None, 'n_estimators': 110, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 1e-05, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
#     '2020-02-05': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.7, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 13, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 1e-05, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
#     '2020-02-06': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.7, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
#     '2020-02-07': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.6, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 14, 'min_child_weight': 2, 'missing': None, 'n_estimators': 140, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.9, 'verbosity': 1},
#     '2020-02-08': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.6, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.04, 'max_delta_step': 0, 'max_depth': 14, 'min_child_weight': 1, 'missing': None, 'n_estimators': 140, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.8, 'verbosity': 1},
#     '2020-02-09': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.6, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 12, 'min_child_weight': 2, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.9, 'verbosity': 1},
#     '2020-02-10': {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.6, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 7, 'min_child_weight': 1, 'missing': None, 'n_estimators': 150, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 1e-05, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1},
# }

# %%
from coronavirus_analyzer import CoronavirusAnalyzer, train_and_predict
# get_data_params = {'predict_day_cnt': 1, 'sample_weight_type': 1, 'sample_weight_power': 1 / 2.0,
#                    'use_move_in': False}  # 'use_last_ma3': True, 'use_last_ma3_rank': False
get_data_params = {'predict_day_cnt': predict_day_cnt, 'use_move_in_corr': False, 'use_last_ma3': True,
                   'selected_regions': selected_regions, 'n_days': 7}  # , 'use_move_out': True

# xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1,
#               'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06,
#               'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None,
#               'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001,
#               'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 
              'colsample_bytree': 0.9, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.06, 
              'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 
              'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 
              'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# xgb_params = {}
predict = train_and_predict(first_date, last_date, print_log=True, 
                            get_data_params=get_data_params, xgb_params=xgb_params)
# Out:
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.8349901984372208
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.9, 'gamma': 0.0, 'importance_type': 'gain', 'learning_rate': 0.06, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None, 'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
# 模型 score：0.8435056845698303
# ...

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
analyzer = CoronavirusAnalyzer()
df_predict_real2, df_compare2 = analyzer.get_df_predict_real(predict, 2)
# Out:
# 2020-02-13 23:26:59,268 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-13），如下这些地区没有新增的确诊人数：广西、台湾、澳门、青海、西藏，如下这些地区没有任何疫情数据变化：台湾、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。

# %%
from coronavirus_analyzer import CoronavirusAnalyzer, train_and_predict
# get_data_params = {'predict_day_cnt': 1, 'use_move_in_injured': False, 'use_in_out_rate': False,
#                    'sample_weight_type': 3, 'sample_weight_power': 1 / 2.0, 'use_last_ma3': True}  # 'use_last_ma3': True, 'use_last_ma3_rank': False
get_data_params = {'predict_day_cnt': predict_day_cnt, 'use_move_in_injured': False, 
                   'use_in_out_rate': False, 'selected_regions': selected_regions}
# xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1,
#               'colsample_bytree': 0.9, 'gamma': 0.3, 'importance_type': 'gain', 'learning_rate': 0.06,
#               'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 5, 'missing': None,
#               'n_estimators': 115, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0.0001,
#               'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1.0, 'verbosity': 1}
xgb_params = {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 
              'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 
              'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 4, 'missing': None, 
              'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 
              'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
predict = train_and_predict(first_date, last_date, print_log=True, 
                            get_data_params=get_data_params, xgb_params=xgb_params)
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
analyzer = CoronavirusAnalyzer()
df_predict_real1, df_compare1 = analyzer.get_df_predict_real(predict, 1)
# Out:
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 4, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
# 模型 score：0.7934335868095818
# xgb_params: {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'gamma': 0.6, 'importance_type': 'gain', 'learning_rate': 0.07, 'max_delta_step': 0, 'max_depth': 4, 'min_child_weight': 4, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:gamma', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 0.7, 'verbosity': 1}
# 模型 score：0.7940540334231584
# ...

# %%
# 直接使用前一天的值作为预测值 df_compare0，比较准确率提高程度
from util.util import Util
from coronavirus_analyzer import CoronavirusAnalyzer
analyzer = CoronavirusAnalyzer()
df_real = analyzer.df_virus_daily_inc_injured
del df_real['全国']
del df_real['湖北']
del df_real['武汉']
del df_real['香港']
del df_real['澳门']
del df_real['台湾']
df_predict = Util.shift_date_index(df_real, 1, False)
df_compare0 = (df_predict - df_real).loc[first_date: last_date]  # .iloc[:-2]
if selected_regions is not None:
    df_compare0 = df_compare0[selected_regions]
analyzer.predict_compare(df_compare1.loc[first_date: last_date],
                         df_compare3.loc[first_date: last_date])[0].sum()
# Out:
# 2020-02-13 23:27:07,993 - CoronavirusAnalyzer - WARNING - 在最后一天（2020-02-13），如下这些地区没有新增的确诊人数：广西、台湾、澳门、青海、西藏，如下这些地区没有任何疫情数据变化：台湾、西藏。请确保这些地区已经公布了最后一天的数据（一般是后面一天上午公布），否则分析出来的结果可能不准确。
# 0.5833333333333334

# %%
# select_regions = ['广东', '上海', '北京', '天津', '江苏', '浙江', '福建']
# select_regions = ['江苏', '山西', '浙江', '四川', '山东', '福建', '陕西', ]#'广东', '安徽', '北京', '上海', '甘肃', '河南', '天津', '辽宁', '江西']
select_regions = None
# select_regions = ['江苏', '山西', '浙江', '四川', '山东', '陕西', '安徽', '福建', '广东', '北京', '天津', '甘肃', '河南', '上海', '江西']
# select_regions = [r for r in df_compare0.columns if r not in select_regions]
print(select_regions)
df0 = df_compare0.loc[first_date: last_date]
df1 = df_compare1.loc[first_date: last_date]
df2 = df_compare2.loc[first_date: last_date]
df3 = df_compare3.loc[first_date: last_date]
if select_regions is not None:
    df0 = df0[select_regions]
    df1 = df1[select_regions]
    df2 = df2[select_regions]
    df3 = df3[select_regions]
if predict_day_cnt > 1:
    df0 = df0.iloc[: -(predict_day_cnt - 1)]
for i in range(7):
    sum0 = abs(df0.iloc[i]).sum().sum()
    sum1 = abs(df1.iloc[i]).sum().sum()
    sum2 = abs(df2.iloc[i]).sum().sum()
    sum3 = abs(df3.iloc[i]).sum().sum()
    print(sum2-sum1)
# Out:
# None
# -1.4000000000000057
# -23.299999999999983
# 14.400000000000034
# 9.80000000000004
# -12.099999999999966
# 14.10000000000008
# -8.500000000000028

# %%
size = df0.size
start = 0
arr = np.array([abs(df0.values[start:]).sum(), abs(df1.values[start:]).sum(), \
abs(df2.values[start:]).sum(), abs(df3.values[start:]).sum()])
print(arr)
print(arr / size)
# Out:
# [2031.  1785.5 1779.8 1739.5]
# [5.64166667 4.95972222 4.94388889 4.83194444]

# %%
df = pd.DataFrame([abs(df0.values).sum(axis=1), abs(df1.values).sum(axis=1), 
                   abs(df2.values).sum(axis=1), abs(df3.values).sum(axis=1)], 
                   index=['预测0', '预测1', '预测2', '预测3'], columns=df_predict_real1.index).T
df /= df0.shape[1]
df
# Out:
#                  预测0       预测1        预测2       预测3
# 2020-02-01  5.666667  4.396667   4.350000  4.966667
# 2020-02-02  4.500000  5.053333   4.276667  4.940000
# 2020-02-03  7.866667  9.690000  10.170000  9.896667
# 2020-02-04  8.133333  4.896667   5.223333  4.553333
# 2020-02-05  5.700000  5.143333   4.740000  4.720000
# 2020-02-06  4.933333  4.350000   4.820000  4.113333
# 2020-02-07  6.833333  6.286667   6.003333  5.546667
# 2020-02-08  5.366667  4.266667   3.843333  3.933333
# 2020-02-09  5.000000  4.243333   4.630000  4.220000
# 2020-02-10  4.966667  3.683333   4.040000  3.823333
# 2020-02-11  4.333333  3.926667   3.530000  3.530000
# 2020-02-12  4.400000  3.580000   3.700000  3.740000

# %%
df = pd.concat([df_predict_real1, df_predict_real2.iloc[:, 0::2]], axis=1).sort_index(axis=1)
s_sorted_corr = analyzer.get_move_in_injured_corr().sort_values(ascending=False)
s_sorted_corr = s_sorted_corr[np.isin(s_sorted_corr.index.values, df.columns.levels[0].values)]
data = []
for region in s_sorted_corr.index:
    delta = abs(df[region]['预测1'] - df[region]['实际']) - abs(df[region]['预测2'] - df[region]['实际'])
    data.append(delta)
df = pd.DataFrame(data, s_sorted_corr.index).T
df.sum(axis=0)
# Out:
# 江苏      0.3
# 四川     -2.0
# 安徽     -7.2
# 山东      6.6
# 浙江     25.3
# 河北     10.2
# 甘肃     -1.2
# 福建      1.7
# 广西      4.6
# 山西     -2.3
# 海南     -0.6
# 天津      1.1
# 江西     -1.0
# 北京     16.1
# 云南     -2.0
# 内蒙古    -3.4
# 陕西      7.1
# 宁夏      4.9
# 河南     -1.3
# 广东      2.7
# 贵州     -0.5
# 辽宁     -0.4
# 吉林      3.6
# 黑龙江   -14.7
# 重庆    -14.9
# 上海     -7.4
# 新疆     -0.2
# 湖南     -9.6
# 青海     -2.2
# 西藏      3.4
# dtype: float64
